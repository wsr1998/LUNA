# %%
import func
from importlib import reload

# %%
reload(func)
simu_loc='simu/TNG100_z0.1.csv'
base_loc='data0325/'
save_loc='matched_data/'
for z_SBL_ls in [[0.1,26.5],[0.1,27.0],[0.1,27.5],[0.1,28.0]]:
    file_loc='mock_z{}_SBL{}.csv'.format(*z_SBL_ls)
    ETG_df,LTG_df,TNG_df=func.main_compare_mock_simu(base_loc+file_loc,simu_loc,classify_mod='sSFR_&_VelDisp',z_SBL_ls=z_SBL_ls,proj=0,save_loc=save_loc)
# Out:
# The current simulation is TNG100 and classify_mod is sSFR_&_VelDisp.
# All: 22018   , ETG: 7049    , LTG: 14969
# number of central galaxies
# All: 12244   , ETG: 1665    , LTG: 10579
# number of satellite galaxies
# All: 9774    , ETG: 5384    , LTG: 4390
# ...
# The current mock is z=0.1 and SBL=26.5 and classify_mod is sSFR_&_VelDisp
# All: 1282    , ETG: 672     , LTG: 610
# ...
# ETG:
# The values of matched/all galaxies is 611/672
# There are 609 central galaxies and 2 satellite galaxies
# ...
# LTG:
# The values of matched/all galaxies is 554/610
# There are 554 central galaxies and 0 satellite galaxies
# ...
# TNG:
# The values of matched/all galaxies is 1267/1282
# There are 1265 central galaxies and 2 satellite galaxies
# ...
#
# The current simulation is TNG100 and classify_mod is sSFR_&_VelDisp.
# All: 22018   , ETG: 7049    , LTG: 14969
# number of central galaxies
# All: 12244   , ETG: 1665    , LTG: 10579
# number of satellite galaxies
# All: 9774    , ETG: 5384    , LTG: 4390
# ...
